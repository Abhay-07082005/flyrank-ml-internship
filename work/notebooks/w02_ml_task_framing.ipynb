# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Abhay-07082005/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is a classification problem because the goal is to predict whether a piece of content belongs to a category such as high-performing or low-performing based on historical data. The model learns from previous examples and predicts the category for new content.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-99e8c21f-bfca-4ea7-9fc6-2c809d14457f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99e8c21f-bfca-4ea7-9fc6-2c809d14457f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2. Target or proxy
#
# The target is the content performance category (High or Low).
#
# The label comes from observed historical outcomes such as engagement, clicks, views, or other performance metrics. If the dataset does not contain this label, it can be created using a defined threshold based on those observed values.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-87217946-be21-490a-bc4f-7c1f7435252d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87217946-be21-490a-bc4f-7c1f7435252d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('content_refresh_anonymized.csv')

print('Shape:', df.shape)
df.head()

# %% [markdown]
# ## 3. Success metric
#
# The success metric is F1 Score because it balances precision and recall and is appropriate when the classes are imbalanced. A higher F1 Score indicates better classification performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("YOUR_DATASET.csv")

df.head()
print(df.shape)
print(df.columns)

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# Machine learning is better than a fixed rule because content performance depends on many interacting factors such as topic, audience behavior, timing, engagement history, and other features. These relationships are too complex for simple if-else rules, while an ML model can learn patterns from historical data and make better predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
