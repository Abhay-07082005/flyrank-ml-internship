# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Abhay-07082005/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
from google.colab import userdata

token = userdata.get("HF_TOKEN")
print(token is not None)
# Out:
# True

# %%
from google.colab import userdata

# %%
import duckdb
con = ...

# %%
duckdb.connect(...)
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# /tmp/ipykernel_902/3826095605.py in <cell line: 0>()
# ----> 1 duckdb.connect(...)
#
# InvalidInputException: Invalid Input Error: Please provide either a str or a pathlib.Path, not <class 'ellipsis'>

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

con.sql("""
SELECT *
FROM search_intelligence
WHERE month='2026-03'
LIMIT 10
""").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_902/620588489.py in <cell line: 0>()
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#       3
# ----> 4 con.sql("""
#       5 SELECT *
#       6 FROM search_intelligence
#
# NameError: name 'con' is not defined

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
# One row represents one report_date × client × content record for March 2026.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
con.sql("""
SELECT report_date, client_id, content_id, COUNT(*) c
FROM fact_content_daily_performance
WHERE month='2026-03'
GROUP BY report_date, client_id, content_id
HAVING c > 1
LIMIT 5;
""").df()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_902/3377100129.py in <cell line: 0>()
#       1 # This cell is for CODE (numbers, a query, a check).
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ----> 3 con.sql("""
#       4 SELECT report_date, client_id, content_id, COUNT(*) c
#       5 FROM fact_content_daily_performance
#
# AttributeError: 'ellipsis' object has no attribute 'sql'

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
